# %% [markdown]
# <a href="https://colab.research.google.com/github/LordFlixXx/DownTorr/blob/main/DownTorr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar o webtorrent-cli
# !npm install -g webtorrent-cli
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙npm warn deprecated xmldom@0.1.31: Deprecated due to CVE-2021-21366 resolved in 0.5.0
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏npm warn deprecated ecstatic@4.1.4: This package is unmaintained and deprecated. See the GH Issue 259.
# ⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦
# added 336 packages in 42s
# ⠧
# ⠧64 packages are looking for funding
# ⠧  run `npm fund` for details
# ⠧

# %%
# Montar o Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importar bibliotecas necessárias
import subprocess
import requests
import os
import threading
import json
import shutil
from queue import Queue



# Definir o caminho do arquivo de registros no Google Drive
records_file = '/content/drive/My Drive/Projetos/Filmes.net.eu.org/records.json'
subtitles_save_path = '/content/drive/My Drive/Projetos/Filmes.net.eu.org/Legendas'

# Função para carregar registros de um arquivo JSON
def load_records(file_path):
    if os.path.exists(file_path):
        with open(file_path, 'r') as file:
            return json.load(file)
    return {}

# Função para salvar registros em um arquivo JSON
def save_records(file_path, records):
    with open(file_path, 'w') as file:
        json.dump(records, file, indent=4)

# Função para renomear o arquivo de vídeo
def rename_video_file(file_path, imdb_code, title_long, movie_id, hash, quality):
    ext = os.path.splitext(file_path)[1]
    new_file_name = f"{imdb_code[2:]}-{title_long}-{movie_id}-{hash}-{quality}{ext}"
    new_file_path = os.path.join(os.path.dirname(file_path), new_file_name)
    os.rename(file_path, new_file_path)
    return new_file_path



# Função para obter os detalhes do filme usando o movie_id
def get_movie_details(movie_id):
    url = f'https://yts.mx/api/v2/movie_details.json?movie_id={movie_id}&with_images=true&with_cast=true'
    response = requests.get(url)
    try:
        response_data = response.json()
        if response_data['status'] == 'ok':
            return response_data['data']['movie']
        else:
            raise Exception(f"Falha ao obter os detalhes do filme da API do YTS. Status: {response_data['status']}")
    except json.JSONDecodeError:
        raise Exception("Falha ao decodificar a resposta JSON da API do YTS")

# Função para obter os detalhes do filme usando o imdb_code
def get_movie_details_by_imdb(imdb_code):
    url = f'https://yts.mx/api/v2/movie_details.json?imdb_id={imdb_code}&with_images=true&with_cast=true'
    response = requests.get(url)
    try:
        response_data = response.json()
        if response_data['status'] == 'ok':
            return response_data['data']['movie']
        else:
            raise Exception(f"Falha ao obter os detalhes do filme da API do YTS. Status: {response_data['status']}")
    except json.JSONDecodeError:
        raise Exception("Falha ao decodificar a resposta JSON da API do YTS")



# Função para fazer o download de um arquivo usando o hash
def download_torrent(hash, save_path):
    magnet_link = (
        f'magnet:?xt=urn:btih:{hash}&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce'
    )
    print(f"Iniciando download do torrent: {magnet_link}")
    subprocess.run(['webtorrent', magnet_link, '--out', save_path])
    print(f"Download do torrent concluído: {magnet_link}")

# Função para fazer o upload de um arquivo para o Gofile.io
def upload_to_gofile(video_file_path, api_token):
    try:
        # Obter um servidor do Gofile.io
        response = requests.get('https://api.gofile.io/servers')
        response_data = response.json()
        if response_data['status'] == 'ok':
            server = response_data['data']['servers'][0]['name']
            print(f"Servidor selecionado: {server}")
        else:
            raise Exception("Falha ao obter um servidor do Gofile.io")

        # Fazer upload do vídeo para o Gofile.io
        upload_url = f'https://{server}.gofile.io/uploadFile'
        with open(video_file_path, 'rb') as video_file:
            headers = {
                'Authorization': f'Bearer {api_token}'
            }
            response = requests.post(upload_url, headers=headers, files={'file': video_file})

        # Imprimir a resposta bruta da API para depuração
        print("Resposta bruta da API do Gofile.io:", response.text)

        # Analisar a resposta para obter o link de download
        response_data = response.json()
        if response_data['status'] == 'ok':
            download_link = response_data['data']['downloadPage']
            file_id = response_data['data']['id']
            print(f'Vídeo enviado com sucesso! Link para download: {download_link}')
            return download_link, file_id
        else:
            print('Falha ao enviar o vídeo. Resposta:', response_data)
            return None, None
    except json.JSONDecodeError:
        print("Falha ao decodificar a resposta JSON. Resposta bruta:", response.text)
        return None, None
    except Exception as e:
        print(f"Ocorreu um erro ao fazer o upload para o Gofile.io: {e}")
        return None, None

# Função para fazer o upload de um arquivo para o Hydrax
def upload_to_hydrax(video_file_path):
    try:
        url = 'http://up.hydrax.net/276350a6150b6257eb928d9d3aba9fbf'
        file_name = os.path.basename(video_file_path)
        file_type = 'video/mp4'
        files = { 'file': (file_name, open(video_file_path, 'rb'), file_type) }

        response = requests.post(url, files=files)
        print("Resposta da API do Hydrax:", response.text)
        try:
            response_data = response.json()
            if response_data['status'] == 'ok':
                return response_data['slug'], response_data['urlIframe']
            else:
                return None, None
        except json.JSONDecodeError:
            print("Falha ao decodificar a resposta JSON. Resposta bruta:", response.text)
            return None, None
    except Exception as e:
        print(f"Ocorreu um erro ao fazer o upload para o Hydrax: {e}")
        return None, None

# Função para salvar legendas no Google Drive
def save_subtitles_to_drive(movie_id, hash, subtitle_file_path):
    drive_path = os.path.join(subtitles_save_path, str(movie_id), hash)
    os.makedirs(drive_path, exist_ok=True)
    shutil.copy(subtitle_file_path, drive_path)
    print(f"Legenda salva no Google Drive: {subtitle_file_path}")



# Função principal de processamento
def process_movie(movie_details, api_token, save_path):
    imdb_code = movie_details["imdb_code"]
    movie_id = movie_details["id"]

    # Carregar registros existentes
    records = load_records(records_file)

    if imdb_code in records:
        # Verificar se todos os hashes já foram processados
        all_hashes_processed = True
        for torrent in records[imdb_code]["torrents"]:
            if torrent.get("status") != "Hash processado":
                all_hashes_processed = False
                break
        if all_hashes_processed:
            print(f"Todos os hashes do filme {imdb_code} já foram processados. Pulando para o próximo filme.")
            return

        # Atualizar informações existentes
        records[imdb_code].update({
            "id": movie_details["id"],
            "url": movie_details["url"],
            "title": movie_details["title"],
            "title_english": movie_details["title_english"],
            "title_long": movie_details["title_long"],
            "year": movie_details["year"],
            "rating": movie_details["rating"],
            "runtime": movie_details["runtime"],
            "genres": movie_details["genres"],
            "like_count": movie_details["like_count"],
            "description_full": movie_details["description_full"],
            "yt_trailer_code": movie_details["yt_trailer_code"],
            "language": movie_details["language"],
            "background_image": movie_details["background_image"],
            "small_cover_image": movie_details["small_cover_image"],
            "medium_cover_image": movie_details["medium_cover_image"],
            "large_cover_image": movie_details["large_cover_image"],
            "medium_screenshot_image1": movie_details["medium_screenshot_image1"],
            "medium_screenshot_image2": movie_details["medium_screenshot_image2"],
            "medium_screenshot_image3": movie_details["medium_screenshot_image3"],
            "large_screenshot_image1": movie_details["large_screenshot_image1"],
            "large_screenshot_image2": movie_details["large_screenshot_image2"],
            "large_screenshot_image3": movie_details["large_screenshot_image3"],
            "cast": movie_details.get("cast", []),
            "torrents": [
                {
                    "url": t["url"],
                    "hash": t["hash"],
                    "quality": t["quality"],
                    "type": t["type"],
                    "video_codec": t["video_codec"],
                    "audio_channels": t["audio_channels"],
                    "size": t["size"],
                    "status": records[imdb_code]["torrents"][i].get("status", "Em processamento"),
                    "downloadPage": records[imdb_code]["torrents"][i].get("downloadPage"),
                    "id": records[imdb_code]["torrents"][i].get("id"),
                    "urlIframe": records[imdb_code]["torrents"][i].get("urlIframe")
                } for i, t in enumerate(movie_details["torrents"])
            ]
        })
    else:
        # Adicionar novo registro
        records[imdb_code] = {
            "id": movie_details["id"],
            "url": movie_details["url"],
            "imdb_code": movie_details["imdb_code"],
            "title": movie_details["title"],
            "title_english": movie_details["title_english"],
            "title_long": movie_details["title_long"],
            "year": movie_details["year"],
            "rating": movie_details["rating"],
            "runtime": movie_details["runtime"],
            "genres": movie_details["genres"],
            "like_count": movie_details["like_count"],
            "description_full": movie_details["description_full"],
            "yt_trailer_code": movie_details["yt_trailer_code"],
            "language": movie_details["language"],
            "background_image": movie_details["background_image"],
            "small_cover_image": movie_details["small_cover_image"],
            "medium_cover_image": movie_details["medium_cover_image"],
            "large_cover_image": movie_details["large_cover_image"],
            "medium_screenshot_image1": movie_details["medium_screenshot_image1"],
            "medium_screenshot_image2": movie_details["medium_screenshot_image2"],
            "medium_screenshot_image3": movie_details["medium_screenshot_image3"],
            "large_screenshot_image1": movie_details["large_screenshot_image1"],
            "large_screenshot_image2": movie_details["large_screenshot_image2"],
            "large_screenshot_image3": movie_details["large_screenshot_image3"],
            "cast": movie_details.get("cast", []),
            "torrents": [
                {
                    "url": t["url"],
                    "hash": t["hash"],
                    "quality": t["quality"],
                    "type": t["type"],
                    "video_codec": t["video_codec"],
                    "audio_channels": t["audio_channels"],
                    "size": t["size"],
                    "status": "Em processamento",
                    "downloadPage": None,
                    "id": None,
                    "urlIframe": None
                } for t in movie_details["torrents"]
            ]
        }
    save_records(records_file, records)

    # Criar pasta para o imdb_code
    imdb_code_path = os.path.join(save_path, movie_details["imdb_code"])
    os.makedirs(imdb_code_path, exist_ok=True)

    # Fazer o download de todos os arquivos/hash simultaneamente
    threads = []
    for torrent in movie_details["torrents"]:
        if torrent.get("status") == "Hash processado":
            continue
        hash = torrent["hash"]
        quality = torrent["quality"]
        hash_path = os.path.join(imdb_code_path, hash)
        os.makedirs(hash_path, exist_ok=True)
        thread = threading.Thread(target=download_torrent, args=(hash, hash_path))
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()

    print("Todos os downloads de torrents foram concluídos.")

    # Encontrar os arquivos de vídeo baixados, renomear e fazer o upload para o Gofile.io e Hydrax
    for torrent in movie_details["torrents"]:
        if torrent.get("status") == "Hash processado":
            continue
        hash = torrent["hash"]
        hash_path = os.path.join(imdb_code_path, hash)
        for root, dirs, files in os.walk(hash_path):
            for file in files:
                if file.endswith(('.mp4', '.mkv', '.webm', '.avi')):
                    video_file_path = os.path.join(root, file)
                    print(f"Arquivo de vídeo encontrado: {video_file_path}")

                    # Renomear o arquivo de vídeo
                    new_video_file_path = rename_video_file(video_file_path, movie_details["imdb_code"], movie_details["title_long"], movie_details["id"], hash, quality)
                    print(f"Arquivo de vídeo renomeado para: {new_video_file_path}")

                    # Fazer upload para o Gofile.io e Hydrax
                    download_page, file_id = upload_to_gofile(new_video_file_path, api_token)
                    slug, url_iframe = upload_to_hydrax(new_video_file_path)

                    # Atualizar registros com as informações de upload
                    for t in records[imdb_code]["torrents"]:
                        if t["hash"] == hash:
                            t["status"] = "Hash processado"
                            t["downloadPage"] = download_page
                            t["id"] = file_id
                            t["urlIframe"] = url_iframe
                            break
                    save_records(records_file, records)

                    # Encontrar e salvar legendas no Google Drive
                    for subtitle_file in files:
                        if subtitle_file.endswith(('.srt', '.vtt')):
                            subtitle_path = os.path.join(root, subtitle_file)
                            save_subtitles_to_drive(movie_id, hash, subtitle_path)

                    # Deletar a pasta do hash após o processamento
                    shutil.rmtree(hash_path)
                    print(f"Pasta {hash_path} deletada.")

    # Deletar a pasta do imdb_code se todas as pastas de hash foram processadas
    if not os.listdir(imdb_code_path):
        shutil.rmtree(imdb_code_path)
        print(f"Pasta {imdb_code_path} deletada.")



# Função principal
def main():
    save_path = './downloads'
    os.makedirs(save_path, exist_ok=True)
    api_token = 'GpkJkq7tYfBNYsDe0d8DfYm3WOVeseGC'

    # Perguntar ao usuário se deseja processamento automático ou manual
    mode = input("Iniciar processamento automático ou manual? (Digite AUTOMATICO ou MANUAL): ").strip().upper()

    if mode == "AUTOMATICO":
        # Perguntar se deseja continuar a partir do último movie_id processado ou iniciar de um específico
        continue_from_last = input("Deseja continuar a partir do último 'movie_id' processado? (Digite SIM ou NAO): ").strip().upper()
        if continue_from_last == "SIM":
            # Carregar registros existentes
            records = load_records(records_file)
            # Encontrar o último movie_id processado
            last_movie_id = max(int(records[key]["id"]) for key in records)
            movie_id = last_movie_id - 1
        else:
            movie_id = int(input("Informe o número do 'movie_id' que devo iniciar: ").strip())

        # Processar filmes de forma decrescente
        while movie_id > 0:
            try:
                # Obter os detalhes do filme
                movie_details = get_movie_details(movie_id)
                process_movie(movie_details, api_token, save_path)
                movie_id -= 1
            except Exception as e:
                print(f"Ocorreu um erro no processamento: {e}")
                movie_id -= 1

    elif mode == "MANUAL":
        # Perguntar ao usuário qual parâmetro deseja usar para iniciar o processamento
        parameter = input("Informe o 'movie_id', 'imdb_code' ou 'hash' que deseja processar: ").strip().upper()

        if parameter.isdigit():
            # Processar usando movie_id
            movie_details = get_movie_details(int(parameter))
            process_movie(movie_details, api_token, save_path)
        elif parameter.startswith("TT"):
            # Processar usando imdb_code
            movie_details = get_movie_details_by_imdb(parameter)
            process_movie(movie_details, api_token, save_path)
        else:
            # Processar usando hash
            hash = parameter
            hash_path = './downloads/temp'
            os.makedirs(hash_path, exist_ok=True)
            download_torrent(hash, hash_path)
            print(f"Download do hash {hash} concluído.")

    else:
        print("Modo inválido. Por favor, digite AUTOMATICO ou MANUAL.")

if __name__ == "__main__":
    main()
# Out:
# Iniciando download do torrent: magnet:?xt=urn:btih:58D89037C6B7134839E8C05F8C16B62E4D103A8C&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce
# Iniciando download do torrent: magnet:?xt=urn:btih:0CD37254BA0F576511D1047129DC924B905C3DAF&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce
# Download do torrent concluído: magnet:?xt=urn:btih:0CD37254BA0F576511D1047129DC924B905C3DAF&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce
# Download do torrent concluído: magnet:?xt=urn:btih:58D89037C6B7134839E8C05F8C16B62E4D103A8C&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce
# Todos os downloads de torrents foram concluídos.
# Arquivo de vídeo encontrado: ./downloads/tt27698170/58D89037C6B7134839E8C05F8C16B62E4D103A8C/Mother Mafia (2024) [720p] [WEBRip] [YTS.MX]/Mother.Mafia.2024.720p.WEBRip.x264.AAC-[YTS.MX].mp4
# Arquivo de vídeo renomeado para: ./downloads/tt27698170/58D89037C6B7134839E8C05F8C16B62E4D103A8C/Mother Mafia (2024) [720p] [WEBRip] [YTS.MX]/27698170-Mother Mafia (2024)-67246-58D89037C6B7134839E8C05F8C16B62E4D103A8C-1080p.mp4
# Servidor selecionado: store8
# Resposta bruta da API do Gofile.io: {"data":{"createTime":1740866957,"downloadPage":"https://gofile.io/d/uIsenN","id":"1a33ff76-57e7-40e8-a147-6013836075e4","md5":"8bb0f127eee0bb9ed327edc56112f5cc","mimetype":"video/mp4","modTime":1740866957,"name":"27698170-Mother Mafia (2024)-67246-58D89037C6B7134839E8C05F8C16B62E4D103A8C-1080p.mp4","parentFolder":"e32256b3-9e58-417c-ab7e-3ce6f4b5fc1a","parentFolderCode":"uIsenN","servers":["store-na-phx-1"],"size":779267667,"type":"file"},"status":"ok"}
#
# Vídeo enviado com sucesso! Link para download: https://gofile.io/d/uIsenN
# Resposta da API do Hydrax: {"status":true,"msg":"Complete","slug":"SspuwhSit","urlIframe":"https://short.icu/SspuwhSit"}
# Legenda salva no Google Drive: ./downloads/tt27698170/58D89037C6B7134839E8C05F8C16B62E4D103A8C/Mother Mafia (2024) [720p] [WEBRip] [YTS.MX]/Mother.Mafia.2024.720p.WEBRip.x264.AAC-[YTS.MX].srt
# Pasta ./downloads/tt27698170/58D89037C6B7134839E8C05F8C16B62E4D103A8C deletada.
# Arquivo de vídeo encontrado: ./downloads/tt27698170/0CD37254BA0F576511D1047129DC924B905C3DAF/Mother Mafia (2024) [1080p] [WEBRip] [5.1] [YTS.MX]/Mother.Mafia.2024.1080p.WEBRip.x264.AAC5.1-[YTS.MX].mp4
# Arquivo de vídeo renomeado para: ./downloads/tt27698170/0CD37254BA0F576511D1047129DC924B905C3DAF/Mother Mafia (2024) [1080p] [WEBRip] [5.1] [YTS.MX]/27698170-Mother Mafia (2024)-67246-0CD37254BA0F576511D1047129DC924B905C3DAF-1080p.mp4
# Servidor selecionado: store9
# Resposta bruta da API do Gofile.io: {"data":{"createTime":1740867032,"downloadPage":"https://gofile.io/d/sdYJ1j","id":"2cd3799d-ae0f-462a-a052-575e5dce0a21","md5":"99b905d1ebba486fd59ac12598419103","mimetype":"video/mp4","modTime":1740867032,"name":"27698170-Mother Mafia (2024)-67246-0CD37254BA0F576511D1047129DC924B905C3DAF-1080p.mp4","parentFolder":"9ea621a8-d6d6-4966-9d06-cecb916841fc","parentFolderCode":"sdYJ1j","servers":["store-na-phx-1"],"size":1601591585,"type":"file"},"status":"ok"}
#
# Vídeo enviado com sucesso! Link para download: https://gofile.io/d/sdYJ1j
# Resposta da API do Hydrax: {"status":true,"msg":"Complete","slug":"HsKiT1BfA","urlIframe":"https://short.icu/HsKiT1BfA"}
# Legenda salva no Google Drive: ./downloads/tt27698170/0CD37254BA0F576511D1047129DC924B905C3DAF/Mother Mafia (2024) [1080p] [WEBRip] [5.1] [YTS.MX]/Mother.Mafia.2024.1080p.WEBRip.x264.AAC5.1-[YTS.MX].srt
# Pasta ./downloads/tt27698170/0CD37254BA0F576511D1047129DC924B905C3DAF deletada.
# Pasta ./downloads/tt27698170 deletada.
# Iniciando download do torrent: magnet:?xt=urn:btih:BDAA8CB88F0131D59A80D4649E7CAA15890B510A&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce
# Iniciando download do torrent: magnet:?xt=urn:btih:4FC841341291870C98E53613A98F075E9F06F554&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce
# Download do torrent concluído: magnet:?xt=urn:btih:BDAA8CB88F0131D59A80D4649E7CAA15890B510A&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce
# Download do torrent concluído: magnet:?xt=urn:btih:4FC841341291870C98E53613A98F075E9F06F554&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce
# Todos os downloads de torrents foram concluídos.
# Arquivo de vídeo encontrado: ./downloads/tt28036831/BDAA8CB88F0131D59A80D4649E7CAA15890B510A/Ghost Cat Anzu (2024) [MULTI] [720p] [WEBRip] [YTS.MX]/Ghost.Cat.Anzu.2024.MULTI.720p.WEBRip.x264.AAC-[YTS.MX].mp4
# Arquivo de vídeo renomeado para: ./downloads/tt28036831/BDAA8CB88F0131D59A80D4649E7CAA15890B510A/Ghost Cat Anzu (2024) [MULTI] [720p] [WEBRip] [YTS.MX]/28036831-Ghost Cat Anzu (2024)-67245-BDAA8CB88F0131D59A80D4649E7CAA15890B510A-1080p.mp4
# Servidor selecionado: store-na-phx-1
# Resposta bruta da API do Gofile.io: {"data":{"createTime":1740867291,"downloadPage":"https://gofile.io/d/cryZ0O","id":"7274dd0f-73d9-4d68-9603-de95feb6126d","md5":"0434f441cfb3b8b0c606ef08561f24ab","mimetype":"video/mp4","modTime":1740867291,"name":"28036831-Ghost Cat Anzu (2024)-67245-BDAA8CB88F0131D59A80D4649E7CAA15890B510A-1080p.mp4","parentFolder":"e1ca3f66-cc11-4fbb-9c7c-0a051e82f904","parentFolderCode":"cryZ0O","servers":["store8"],"size":874730324,"type":"file"},"status":"ok"}
#
# Vídeo enviado com sucesso! Link para download: https://gofile.io/d/cryZ0O
# Resposta da API do Hydrax: {"status":true,"msg":"Complete","slug":"qzNvv8Bg5","urlIframe":"https://short.icu/qzNvv8Bg5"}
# Pasta ./downloads/tt28036831/BDAA8CB88F0131D59A80D4649E7CAA15890B510A deletada.
# Arquivo de vídeo encontrado: ./downloads/tt28036831/4FC841341291870C98E53613A98F075E9F06F554/Ghost Cat Anzu (2024) [MULTI] [1080p] [WEBRip] [YTS.MX]/Ghost.Cat.Anzu.2024.MULTI.1080p.WEBRip.x264.AAC-[YTS.MX].mp4
# Arquivo de vídeo renomeado para: ./downloads/tt28036831/4FC841341291870C98E53613A98F075E9F06F554/Ghost Cat Anzu (2024) [MULTI] [1080p] [WEBRip] [YTS.MX]/28036831-Ghost Cat Anzu (2024)-67245-4FC841341291870C98E53613A98F075E9F06F554-1080p.mp4
# Servidor selecionado: store3
# Resposta bruta da API do Gofile.io: {"data":{"createTime":1740867374,"downloadPage":"https://gofile.io/d/JD3Gwc","id":"6ef67a33-d24a-4393-90c0-6dd122fb6e11","md5":"8958fb7996c8e58e7ddae7a54b8b8980","mimetype":"video/mp4","modTime":1740867374,"name":"28036831-Ghost Cat Anzu (2024)-67245-4FC841341291870C98E53613A98F075E9F06F554-1080p.mp4","parentFolder":"b7744da4-7cf9-4f46-abf8-5b7bfa7e14c6","parentFolderCode":"JD3Gwc","servers":["store-na-phx-1"],"size":1622286384,"type":"file"},"status":"ok"}
#
# Vídeo enviado com sucesso! Link para download: https://gofile.io/d/JD3Gwc
# Resposta da API do Hydrax: {"status":true,"msg":"Complete","slug":"hLnM04rGQ","urlIframe":"https://short.icu/hLnM04rGQ"}
# Pasta ./downloads/tt28036831/4FC841341291870C98E53613A98F075E9F06F554 deletada.
# Pasta ./downloads/tt28036831 deletada.
# Iniciando download do torrent: magnet:?xt=urn:btih:111EBD8111E64C28A3CA2C4BA4717A3F5066884A&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2FannounceIniciando download do torrent: magnet:?xt=urn:btih:8BA6F143CB028F1EF75AE970E3D928761FA10B10&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk ...
#
# Download do torrent concluído: magnet:?xt=urn:btih:111EBD8111E64C28A3CA2C4BA4717A3F5066884A&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce
# Download do torrent concluído: magnet:?xt=urn:btih:8BA6F143CB028F1EF75AE970E3D928761FA10B10&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce
# Todos os downloads de torrents foram concluídos.
# Arquivo de vídeo encontrado: ./downloads/tt6176336/111EBD8111E64C28A3CA2C4BA4717A3F5066884A/Hagen (2024) [720p] [BluRay] [YTS.MX]/Hagen.2024.720p.BluRay.x264.AAC-[YTS.MX].mp4
# Arquivo de vídeo renomeado para: ./downloads/tt6176336/111EBD8111E64C28A3CA2C4BA4717A3F5066884A/Hagen (2024) [720p] [BluRay] [YTS.MX]/6176336-Hagen (2024)-67244-111EBD8111E64C28A3CA2C4BA4717A3F5066884A-1080p.mp4
# Servidor selecionado: store9
# Resposta bruta da API do Gofile.io: {"data":{"createTime":1740867954,"downloadPage":"https://gofile.io/d/gLJhOc","id":"15dc4877-49ec-49d1-b0fd-3ea1c260c7e1","md5":"012e8a3a140022335af17c9aa81d1c9b","mimetype":"video/mp4","modTime":1740867954,"name":"6176336-Hagen (2024)-67244-111EBD8111E64C28A3CA2C4BA4717A3F5066884A-1080p.mp4","parentFolder":"fed04744-b77d-4013-bad7-214e32d0d1bf","parentFolderCode":"gLJhOc","servers":["store9"],"size":1340069958,"type":"file"},"status":"ok"}
#
# Vídeo enviado com sucesso! Link para download: https://gofile.io/d/gLJhOc
# Resposta da API do Hydrax: {"status":true,"msg":"Complete","slug":"ypaBYvIoF","urlIframe":"https://short.icu/ypaBYvIoF"}
# Legenda salva no Google Drive: ./downloads/tt6176336/111EBD8111E64C28A3CA2C4BA4717A3F5066884A/Hagen (2024) [720p] [BluRay] [YTS.MX]/Hagen.2024.720p.BluRay.x264.AAC-[YTS.MX].srt
# Pasta ./downloads/tt6176336/111EBD8111E64C28A3CA2C4BA4717A3F5066884A deletada.
# Arquivo de vídeo encontrado: ./downloads/tt6176336/8BA6F143CB028F1EF75AE970E3D928761FA10B10/Hagen (2024) [1080p] [BluRay] [5.1] [YTS.MX]/Hagen.2024.1080p.BluRay.x264.AAC5.1-[YTS.MX].mp4
# Arquivo de vídeo renomeado para: ./downloads/tt6176336/8BA6F143CB028F1EF75AE970E3D928761FA10B10/Hagen (2024) [1080p] [BluRay] [5.1] [YTS.MX]/6176336-Hagen (2024)-67244-8BA6F143CB028F1EF75AE970E3D928761FA10B10-1080p.mp4
# Servidor selecionado: store-na-phx-1
# Resposta bruta da API do Gofile.io: {"data":{"createTime":1740868081,"downloadPage":"https://gofile.io/d/aW7QoS","id":"71c275c4-d40c-4690-892a-0ea1c9228d74","md5":"46d5bdeb31df9c8c4ea88019da6d3ce5","mimetype":"video/mp4","modTime":1740868081,"name":"6176336-Hagen (2024)-67244-8BA6F143CB028F1EF75AE970E3D928761FA10B10-1080p.mp4","parentFolder":"09fc8af4-0065-4c8c-945b-58f2d1635a88","parentFolderCode":"aW7QoS","servers":["store-na-phx-1"],"size":2750541719,"type":"file"},"status":"ok"}
#
# Vídeo enviado com sucesso! Link para download: https://gofile.io/d/aW7QoS
# Resposta da API do Hydrax: {"status":true,"msg":"Complete","slug":"s4dXPIYdp","urlIframe":"https://short.icu/s4dXPIYdp"}
# Legenda salva no Google Drive: ./downloads/tt6176336/8BA6F143CB028F1EF75AE970E3D928761FA10B10/Hagen (2024) [1080p] [BluRay] [5.1] [YTS.MX]/Hagen.2024.1080p.BluRay.x264.AAC5.1-[YTS.MX].srt
# Pasta ./downloads/tt6176336/8BA6F143CB028F1EF75AE970E3D928761FA10B10 deletada.
# Pasta ./downloads/tt6176336 deletada.
# ...
# Download do torrent concluído: magnet:?xt=urn:btih:B5F70A2DA8681D3E1EFB8E0504D56F3A4CB32290&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce
# Todos os downloads de torrents foram concluídos.
# Arquivo de vídeo encontrado: ./downloads/tt1844770/5EE94FA34644664BB7C097487263BD63AF0CE8AA/Sand Sharks (2012) [720p] [WEBRip] [YTS.MX]/Sand.Sharks.2012.720p.WEBRip.x264.AAC-[YTS.MX].mp4
# Arquivo de vídeo renomeado para: ./downloads/tt1844770/5EE94FA34644664BB7C097487263BD63AF0CE8AA/Sand Sharks (2012) [720p] [WEBRip] [YTS.MX]/1844770-Sand Sharks (2012)-67231-5EE94FA34644664BB7C097487263BD63AF0CE8AA-1080p.mp4
# Servidor selecionado: store-na-phx-1
# Resposta bruta da API do Gofile.io: {"data":{"createTime":1740876519,"downloadPage":"https://gofile.io/d/DfQRRJ","id":"5338f0d1-5698-4514-a0fc-eef4253504c1","md5":"940f9210afc7326a1321372608567be3","mimetype":"video/mp4","modTime":1740876519,"name":"1844770-Sand Sharks (2012)-67231-5EE94FA34644664BB7C097487263BD63AF0CE8AA-1080p.mp4","parentFolder":"4b68d2cd-bf87-46d2-b0dc-d3bcec294726","parentFolderCode":"DfQRRJ","servers":["cold4"],"size":876512169,"type":"file"},"status":"ok"}
#
# Vídeo enviado com sucesso! Link para download: https://gofile.io/d/DfQRRJ
# Resposta da API do Hydrax: {"status":true,"msg":"Complete","slug":"cXxUXWUye","urlIframe":"https://short.icu/cXxUXWUye"}
# Legenda salva no Google Drive: ./downloads/tt1844770/5EE94FA34644664BB7C097487263BD63AF0CE8AA/Sand Sharks (2012) [720p] [WEBRip] [YTS.MX]/Sand.Sharks.2012.720p.WEBRip.x264.AAC-[YTS.MX].srt
# Pasta ./downloads/tt1844770/5EE94FA34644664BB7C097487263BD63AF0CE8AA deletada.
# Arquivo de vídeo encontrado: ./downloads/tt1844770/B5F70A2DA8681D3E1EFB8E0504D56F3A4CB32290/Sand Sharks (2012) [1080p] [WEBRip] [5.1] [YTS.MX]/Sand.Sharks.2012.1080p.WEBRip.x264.AAC5.1-[YTS.MX].mp4
# Arquivo de vídeo renomeado para: ./downloads/tt1844770/B5F70A2DA8681D3E1EFB8E0504D56F3A4CB32290/Sand Sharks (2012) [1080p] [WEBRip] [5.1] [YTS.MX]/1844770-Sand Sharks (2012)-67231-B5F70A2DA8681D3E1EFB8E0504D56F3A4CB32290-1080p.mp4
# Servidor selecionado: store-na-phx-1
# Resposta bruta da API do Gofile.io: {"data":{"createTime":1740876603,"downloadPage":"https://gofile.io/d/Ekqjyt","id":"3a348498-fafc-4edb-9f17-adab58db798b","md5":"e96e7d0de3c893eb7e315c3b94a70859","mimetype":"video/mp4","modTime":1740876603,"name":"1844770-Sand Sharks (2012)-67231-B5F70A2DA8681D3E1EFB8E0504D56F3A4CB32290-1080p.mp4","parentFolder":"62f160de-a027-4d7d-a5b3-70acd4ed6490","parentFolderCode":"Ekqjyt","servers":["cold-na-phx-6"],"size":1799920409,"type":"file"},"status":"ok"}
#
# Vídeo enviado com sucesso! Link para download: https://gofile.io/d/Ekqjyt
# Resposta da API do Hydrax: {"status":true,"msg":"Complete","slug":"PYotd3esE","urlIframe":"https://short.icu/PYotd3esE"}
# Legenda salva no Google Drive: ./downloads/tt1844770/B5F70A2DA8681D3E1EFB8E0504D56F3A4CB32290/Sand Sharks (2012) [1080p] [WEBRip] [5.1] [YTS.MX]/Sand.Sharks.2012.1080p.WEBRip.x264.AAC5.1-[YTS.MX].srt
# Pasta ./downloads/tt1844770/B5F70A2DA8681D3E1EFB8E0504D56F3A4CB32290 deletada.
# Pasta ./downloads/tt1844770 deletada.
# Iniciando download do torrent: magnet:?xt=urn:btih:A5DB1503B7BE73EA4C8951C9668DA88FBDAA4956&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2FannounceIniciando download do torrent: magnet:?xt=urn:btih:B3BD0D3CB504CFA411176B9F98DCCE2F366CC12A&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk ...
#
# Download do torrent concluído: magnet:?xt=urn:btih:B3BD0D3CB504CFA411176B9F98DCCE2F366CC12A&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fipv4.tracker.harry.lu%3A80%2Fannounce&tr=https%3A%2F%2Fopentracker.i2p.rocks%3A443%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g.com%3A2095%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.xyz%3A6969%2Fannounce&tr=http%3A%2F%2Fbt.okmp3.ru%3A2710%2Fannounce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gigantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Ftracker.netmap.top%3A6969%2Fannounce&tr=udp%3A%2F%2Fd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fmartin-gebhardt.eu%3A25%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftracker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexistent.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fretracker.lanta.me%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannounce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fannounce&tr=https%3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A6969%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A6969%2Fannounce&tr=https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce

# %% [markdown]
# # Processar Novamente HASHES Pausados::
#
# ---

# %%
import subprocess
import requests
import os
import threading
import json
import shutil
from queue import Queue

# Definir o caminho do arquivo de registros no Google Drive
records_file = '/content/drive/My Drive/records.json'

# Função para carregar registros de um arquivo JSON
def load_records(file_path):
    if os.path.exists(file_path):
        with open(file_path, 'r') as file:
            return json.load(file)
    return {}

# Função para salvar registros em um arquivo JSON
def save_records(file_path, records):
    with open(file_path, 'w') as file:
        json.dump(records, file, indent=4)

# Função para obter os detalhes do filme usando o imdb_code
def get_movie_details(imdb_code):
    response = requests.get(f'https://yts.mx/api/v2/movie_details.json?imdb_id={imdb_code}&with_images=true&with_cast=true')
    response_data = response.json()
    if response_data['status'] == 'ok':
        return response_data['data']['movie']
    else:
        raise Exception("Falha ao obter os detalhes do filme da API do YTS")

# Função para fazer o download de um arquivo usando o hash
def download_torrent(hash, save_path):
    magnet_link = (
        f'magnet:?xt=urn:btih:{hash}&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%'
        '2Fannounce&tr=udp%3A%2F%2Fp4p.arenabg.com%3A1337%2Fannounce&tr=udp%3A%2F%'
        '2Fopen.tracker.cl%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%'
        '3A451%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.org%3A6969%2Fannounce&tr=udp%'
        '3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A'
        '1337%2Fannounce&tr=udp%3A%2F%2Fu4.trakx.crim.ist%3A1337%2Fannounce&tr=udp%'
        '3A%2F%2Ftracker.qu.ax%3A6969%2Fannounce&tr=udp%3A%2F%2Fttk2.nbaonlineservice'
        '.com%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.yemekyedim.com%3A443%2Fanno'
        'unce&tr=https%3A%2F%2Ftracker.bjut.jp%3A443%2Fannounce&tr=https%3A%2F%2Fapi'
        '.ipv4online.uk%3A443%2Fannounce&tr=https%3A%2F%2Ftracker.moeking.me%3A443%'
        '2Fannounce&tr=http%3A%2F%2Ftracker.renfei.net%3A8080%2Fannounce&tr=http%3A%'
        '2F%2Ffleira.no%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.nanoha.org%3A443%'
        '2Fannounce&tr=udp%3A%2F%2Fu6.trakx.crim.ist%3A1337%2Fannounce&tr=udp%3A%2F%'
        '2Fwepzone.net%3A6969%2Fannounce&tr=udp%3A%2F%2Fec2-18-191-163-220.us-east-2'
        '.compute.amazonaws.com%3A6969%2Fannounce&tr=udp%3A%2F%2Fp2p.publictracker.'
        'xyz%3A6969%2Fannounce&tr=https%3A%2F%2Ftracker.gcrenwp.top%3A443%2Fannounce'
        '&tr=udp%3A%2F%2Ftracker.valete.tf%3A9999%2Fannounce&tr=http%3A%2F%2Fbt.okmp'
        '3.ru%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.mywaifu.best%3A6969%2Fannoun'
        'ce&tr=udp%3A%2F%2Fismaarino.com%3A1234%2Fannounce&tr=udp%3A%2F%2Ftracker.gi'
        'gantino.net%3A6969%2Fannounce&tr=https%3A%2F%2Ftr.zukizuki.org%3A443%2Fanno'
        'unce&tr=https%3A%2F%2Ftracker.aburaya.live%3A443%2Fannounce&tr=udp%3A%2F%2F'
        'd40969.acod.regrucolo.ru%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dler.com%'
        '3A6969%2Fannounce&tr=http%3A%2F%2Ftracker.ipv6tracker.ru%3A80%2Fannounce&tr'
        '=udp%3A%2F%2Fudp.tracker.projectk.org%3A23333%2Fannounce&tr=udp%3A%2F%2Ftra'
        'cker.0x7c0.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.gmi.gd%3A6969%2Fann'
        'ounce&tr=http%3A%2F%2Ftaciturn-shadow.spb.ru%3A6969%2Fannounce&tr=udp%3A%2F'
        '%2Ftracker.srv00.com%3A6969%2Fannounce&tr=http%3A%2F%2F0123456789nonexisten'
        't.com%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.tryhackx.org%3A6969%2Fannounce'
        '&tr=http%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=http%3A%2F%2Ftracke'
        'r.netmap.top%3A6969%2Fannounce&tr=http%3A%2F%2Fipv6.rer.lol%3A6969%2Fannoun'
        'ce&tr=udp%3A%2F%2Fwww.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Fretrac'
        'ker.lanta.me%3A2710%2Fannounce&tr=udp%3A%2F%2Fbt.ktrackers.com%3A6666%2Fann'
        'ounce&tr=udp%3A%2F%2Ftracker.darkness.services%3A6969%2Fannounce&tr=https%'
        '3A%2F%2Ftracker.lilithraws.org%3A443%2Fannounce&tr=udp%3A%2F%2Fevan.im%3A69'
        '69%2Fannounce&tr=udp%3A%2F%2Ftracker.filemail.com%3A6969%2Fannounce&tr=udp%'
        '3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=udp%3A%2F%2Ft.overflow.biz%3A69'
        '69%2Fannounce&tr=http%3A%2F%2Ftracker-zhuqiy.dgj055.icu%3A80%2Fannounce&tr='
        'https%3A%2F%2Fretracker.x2k.ru%3A443%2Fannounce&tr=udp%3A%2F%2Ftracker.kmzs'
        '123.cn%3A17272%2Fannounce&tr=udp%3A%2F%2Ftr4ck3r.duckdns.org%3A6969%2Fannoun'
        'ce&tr=https%3A%2F%2Ftorrent.tracker.durukanbal.com%3A443%2Fannounce&tr=udp%'
        '3A%2F%2Ftracker.kmzs123.top%3A17272%2Fannounce&tr=http%3A%2F%2Ftracker.bt4g'
        '.com%3A2095%2Fannounce&tr=http%3A%2F%2Fbt1.archive.org%3A6969%2Fannounce&tr'
        '=http%3A%2F%2Fbt2.archive.org%3A6969%2Fannounce'
    )
    print(f"Iniciando download do torrent: {magnet_link}")
    subprocess.run(['webtorrent', magnet_link, '--out', save_path])
    print(f"Download do torrent concluído: {magnet_link}")

# Função para renomear o arquivo de vídeo
def rename_video_file(file_path, imdb_code, title_long, movie_id, hash, quality):
    ext = os.path.splitext(file_path)[1]
    new_file_name = f"{imdb_code[2:]}-{title_long}-{movie_id}-{hash}-{quality}{ext}"
    new_file_path = os.path.join(os.path.dirname(file_path), new_file_name)
    os.rename(file_path, new_file_path)
    return new_file_path

# Função para fazer o upload de um arquivo para o Gofile.io
def upload_to_gofile(video_file_path, api_token):
    try:
        # Obter um servidor do Gofile.io
        response = requests.get('https://api.gofile.io/servers')
        response_data = response.json()
        if response_data['status'] == 'ok':
            server = response_data['data']['servers'][0]['name']
            print(f"Servidor selecionado: {server}")
        else:
            raise Exception("Falha ao obter um servidor do Gofile.io")

        # Fazer upload do vídeo para o Gofile.io
        upload_url = f'https://{server}.gofile.io/uploadFile'
        with open(video_file_path, 'rb') as video_file:
            headers = {
                'Authorization': f'Bearer {api_token}'
            }
            response = requests.post(upload_url, headers=headers, files={'file': video_file})

        # Imprimir a resposta bruta da API para depuração
        print("Resposta bruta da API do Gofile.io:", response.text)

        # Analisar a resposta para obter o link de download
        response_data = response.json()
        if response_data['status'] == 'ok':
            download_link = response_data['data']['downloadPage']
            file_id = response_data['data']['id']
            print(f'Vídeo enviado com sucesso! Link para download: {download_link}')
            return download_link, file_id
        else:
            print('Falha ao enviar o vídeo. Resposta:', response_data)
            return None, None
    except requests.exceptions.JSONDecodeError:
        print("Falha ao decodificar a resposta JSON. Resposta bruta:", response.text)
        return None, None
    except Exception as e:
        print(f"Ocorreu um erro ao fazer o upload para o Gofile.io: {e}")
        return None, None

# Função para fazer o upload de um arquivo para o Hydrax
def upload_to_hydrax(video_file_path):
    try:
        url = 'http://up.hydrax.net/276350a6150b6257eb928d9d3aba9fbf'
        file_name = os.path.basename(video_file_path)
        file_type = 'video/mp4'
        files = { 'file': (file_name, open(video_file_path, 'rb'), file_type) }

        response = requests.post(url, files=files)
        print("Resposta da API do Hydrax:", response.text)
        response_data = response.json()
        if response_data['status'] == 'ok':
            return response_data['slug'], response_data['urlIframe']
        else:
            return None, None
    except Exception as e:
        print(f"Ocorreu um erro ao fazer o upload para o Hydrax: {e}")
        return None, None

# Função para processar um hash
def process_hash(imdb_code, torrent, save_path, api_token):
    hash = torrent['hash']
    quality = torrent['quality']
    imdb_code_path = os.path.join(save_path, f'temp_{imdb_code}')
    os.makedirs(imdb_code_path, exist_ok=True)
    hash_path = os.path.join(imdb_code_path, hash)
    os.makedirs(hash_path, exist_ok=True)

    print(f"Reprocessando hash: {hash} do filme: {imdb_code}")

    # Fazer o download do torrent
    download_torrent(hash, hash_path)

    # Obter detalhes do filme para obter o id
    movie_details = get_movie_details(imdb_code)
    movie_id = movie_details['id']
    title_long = movie_details['title_long']

    # Encontrar os arquivos de vídeo baixados, renomear e fazer o upload para o Gofile.io e Hydrax
    for root, dirs, files in os.walk(hash_path):
        for file in files:
            if file.endswith(('.mp4', '.mkv', '.webm', '.avi')):
                video_file_path = os.path.join(root, file)
                print(f"Arquivo de vídeo encontrado: {video_file_path}")

                # Renomear o arquivo de vídeo
                new_video_file_path = rename_video_file(video_file_path, imdb_code, title_long, movie_id, hash, quality)
                print(f"Arquivo de vídeo renomeado para: {new_video_file_path}")

                # Fazer upload para o Gofile.io e Hydrax
                download_page, file_id = upload_to_gofile(new_video_file_path, api_token)
                slug, url_iframe = upload_to_hydrax(new_video_file_path)

                # Atualizar registros com as informações de upload
                torrent['status'] = 'Hash processado'
                torrent['slug'] = slug
                torrent['downloadPage'] = download_page
                torrent['id'] = file_id
                torrent['urlIframe'] = url_iframe

                # Deletar a pasta do hash após o processamento
                shutil.rmtree(hash_path)
                print(f"Pasta {hash_path} deletada.")

    # Deletar a pasta temporária do imdb_code
    shutil.rmtree(imdb_code_path)
    print(f"Pasta temporária {imdb_code_path} deletada.")

# Função principal para reprocessar torrents
def reprocess_torrents():
    save_path = './downloads'
    os.makedirs(save_path, exist_ok=True)
    api_token = 'GpkJkq7tYfBNYsDe0d8DfYm3WOVeseGC'
    max_threads = 10

    # Carregar registros existentes
    records = load_records(records_file)

    # Procurar por hashes com status "Em processamento"
    queue = Queue()
    for imdb_code, movie in records.items():
        for torrent in movie['torrents']:
            if torrent['status'] == 'Em processamento':
                queue.put((imdb_code, torrent))

    def worker():
        while not queue.empty():
            imdb_code, torrent = queue.get()
            try:
                process_hash(imdb_code, torrent, save_path, api_token)
            except Exception as e:
                print(f"Ocorreu um erro ao processar o hash {torrent['hash']} do filme {imdb_code}: {e}")
            finally:
                queue.task_done()

    threads = []
    for _ in range(min(max_threads, queue.qsize())):
        thread = threading.Thread(target=worker)
        thread.start()
        threads.append(thread)

    queue.join()

    # Salvar registros atualizados
    save_records(records_file, records)

if __name__ == "__main__":
    reprocess_torrents()
